# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from numpy import loadtxt
from random import *
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
# %matplotlib inline

# %%
#Create the bulk dataset
data1 = pd.read_csv('1.csv', sep=',')
data2 = pd.read_csv('2.csv', sep=',')
data3 = pd.read_csv('3.csv', sep=',')
data4 = pd.read_csv('4.csv', sep=',')
data5 = pd.read_csv('5.csv', sep=',')
data6 = pd.read_csv('6.csv', sep=',')
data7 = pd.read_csv('7.csv', sep=',')
data8 = pd.read_csv('8.csv', sep=',')
data9 = pd.read_csv('9.csv', sep=',')
data10 = pd.read_csv('10.csv', sep=',')
data11 = pd.read_csv('11.csv', sep=',')
data12 = pd.read_csv('12.csv', sep=',')
data13 = pd.read_csv('13.csv', sep=',')
data14 = pd.read_csv('14.csv', sep=',')
data15 = pd.read_csv('15.csv', sep=',')

# %%
#Create the bulk dataset
data1 = pd.read_csv('1.csv', sep=',')
data2 = pd.read_csv('2.csv', sep=',')
data3 = pd.read_csv('3.csv', sep=',')
data4 = pd.read_csv('4.csv', sep=',')
data5 = pd.read_csv('5.csv', sep=',')
data6 = pd.read_csv('6.csv', sep=',')
data7 = pd.read_csv('7.csv', sep=',')
data8 = pd.read_csv('8.csv', sep=',')
data9 = pd.read_csv('9.csv', sep=',')
data10 = pd.read_csv('10.csv', sep=',')
data11 = pd.read_csv('11.csv', sep=',')
data12 = pd.read_csv('12.csv', sep=',')
data13 = pd.read_csv('13.csv', sep=',')
data14 = pd.read_csv('14.csv', sep=',')
data15 = pd.read_csv('15.csv', sep=',')

# %%
data3['tcga_bcr/patient/follow_ups/follow_up/days_to_last_followup/__text'] = randint(900,1000)
data5['tcga_bcr/patient/follow_ups/follow_up/days_to_last_followup/__text'] = randint(900,1000)
data7['tcga_bcr/patient/follow_ups/follow_up/days_to_last_followup/__text'] = randint(900,1000)
data9['tcga_bcr/patient/follow_ups/follow_up/days_to_last_followup/__text'] = randint(900,1000)
data11['tcga_bcr/patient/follow_ups/follow_up/days_to_last_followup/__text'] = randint(900,1000)
data12['tcga_bcr/patient/follow_ups/follow_up/days_to_last_followup/__text'] = randint(900,1000)
data13['tcga_bcr/patient/follow_ups/follow_up/days_to_last_followup/__text'] = randint(900,1000)
data14['tcga_bcr/patient/follow_ups/follow_up/days_to_last_followup/__text'] = randint(900,1000)
data15['tcga_bcr/patient/follow_ups/follow_up/days_to_last_followup/__text'] = randint(900,1000)

# %%
data1.head()
# Out:
#    tcga_bcr/admin/bcr/_xsd_ver       tcga_bcr/admin/bcr/__text  \
# 0                         1.17  Nationwide Children's Hospital
#
#    tcga_bcr/admin/file_uuid/_xsd_ver       tcga_bcr/admin/file_uuid/__text  \
# 0                                2.6  526FDB60-7996-47E4-8DDF-5CF99319780F
#
#    tcga_bcr/admin/batch_number/_xsd_ver tcga_bcr/admin/batch_number/__text  \
# 0                                  1.17                            56.90.0
#
#    tcga_bcr/admin/project_code/_xsd_ver tcga_bcr/admin/project_code/__text  \
# 0                                   NaN                               TCGA
#
#    tcga_bcr/admin/disease_code/_xsd_ver tcga_bcr/admin/disease_code/__text  \
# 0                                   2.6                               BRCA
#
#             ...                         tcga_bcr/_xmlns:shared  \
# 0           ...             http://tcga.nci/bcr/xml/shared/2.7
#
#                         tcga_bcr/_xmlns:brca_shared  \
# ...

# %%
d1 = data1['tcga_bcr/patient/follow_ups/follow_up/days_to_last_followup/__text']
d2 = data2['tcga_bcr/patient/follow_ups/follow_up/days_to_last_followup/__text']
d3 = data3['tcga_bcr/patient/follow_ups/follow_up/days_to_last_followup/__text']
d4 = data4['tcga_bcr/patient/follow_ups/follow_up/days_to_last_followup/__text']
d5 = data5['tcga_bcr/patient/follow_ups/follow_up/days_to_last_followup/__text']
d6 = data6['tcga_bcr/patient/follow_ups/follow_up/days_to_last_followup/__text']
d7 = data7['tcga_bcr/patient/follow_ups/follow_up/days_to_last_followup/__text']
d8 = data8['tcga_bcr/patient/follow_ups/follow_up/days_to_last_followup/__text']
d9 = data9['tcga_bcr/patient/follow_ups/follow_up/days_to_last_followup/__text']
d10 = data10['tcga_bcr/patient/follow_ups/follow_up/days_to_last_followup/__text']
d11 = data11['tcga_bcr/patient/follow_ups/follow_up/days_to_last_followup/__text']
d12 = data12['tcga_bcr/patient/follow_ups/follow_up/days_to_last_followup/__text']
d13 = data13['tcga_bcr/patient/follow_ups/follow_up/days_to_last_followup/__text']
d14 = data14['tcga_bcr/patient/follow_ups/follow_up/days_to_last_followup/__text']
d15= data15['tcga_bcr/patient/follow_ups/follow_up/days_to_last_followup/__text']

# %%
d3.head()
# Out:
# 0    984
# 1    984
# 2    984
# 3    984
# 4    984
# Name: tcga_bcr/patient/follow_ups/follow_up/days_to_last_followup/__text, dtype: int64

# %%
#outDF = pd.concat([data1,data2,data3,data4,data5,data6,data7,data8,data9,data10,data11,data12,data13,data14,data15])

# %%
#outDF.head()

# %%
#outDF.dropna(axis=1, how='any')

# %%
#list(outDF.columns.values)

# %%
#import random
#outDF['_cde'] = outDF['_cde'].apply(lambda v: random.random() * 1000)

# %%
x_vals = pd.read_csv('CIBERSORT.Output_Job14.csv', sep=',',header=None)

# %%
x_vals.head()
# Out:
#              0                    1      2      3                    4   \
# 0  Input Sample                BC_01  BC_02  BC_03              BC_03LN
# 1       sample1  0.19406327581659435      0      0  0.10856565579039577
# 2       sample2   0.3761692049475335      0      0  0.04242034472302899
# 3       sample3   0.2719479143426541      0      0   0.1807606004816538
# 4       sample4  0.49188176710852854      0      0                    0
#
#                     5                    6                    7   \
# 0                BC_04                BC_05                BC_06
# 1  0.08307430452105279   0.2385786600008222  0.11341647581821312
# 2  0.02736060496599689  0.24217414618481348                    0
# 3  0.04032886742636019                    0  0.07803424770190256
# 4  0.09331305703141753                    0   0.0810640974298108
#
#                     8                     9                    10  \
# 0                BC_07               BC_07LN                BC_08
# ...

# %%
x_vals.shape
# Out:
# (16, 17)

# %%
x_vals=x_vals.drop([14,15,16], axis=1)

# %%
x_vals.head()
# Out:
#              0                    1      2      3                    4   \
# 0  Input Sample                BC_01  BC_02  BC_03              BC_03LN
# 1       sample1  0.19406327581659435      0      0  0.10856565579039577
# 2       sample2   0.3761692049475335      0      0  0.04242034472302899
# 3       sample3   0.2719479143426541      0      0   0.1807606004816538
# 4       sample4  0.49188176710852854      0      0                    0
#
#                     5                    6                    7   \
# 0                BC_04                BC_05                BC_06
# 1  0.08307430452105279   0.2385786600008222  0.11341647581821312
# 2  0.02736060496599689  0.24217414618481348                    0
# 3  0.04032886742636019                    0  0.07803424770190256
# 4  0.09331305703141753                    0   0.0810640974298108
#
#                     8                     9                    10  \
# 0                BC_07               BC_07LN                BC_08
# ...

# %%
#Make first row the column names for both singleCellDF and bulkCellDF
new_header = x_vals.iloc[0] #grab the first row for the header
x_vals = x_vals[1:] #take the data less the header row
x_vals.columns = new_header #set the header row as the df header

# %%
x_vals.head()
# Out:
# 0 Input Sample                BC_01 BC_02                BC_03  \
# 1      sample1  0.19406327581659435     0                    0
# 2      sample2   0.3761692049475335     0                    0
# 3      sample3   0.2719479143426541     0                    0
# 4      sample4  0.49188176710852854     0                    0
# 5      sample5  0.27732552765693924     0  0.09358109365128049
#
# 0              BC_03LN                BC_04                BC_05  \
# 1  0.10856565579039577  0.08307430452105279   0.2385786600008222
# 2  0.04242034472302899  0.02736060496599689  0.24217414618481348
# 3   0.1807606004816538  0.04032886742636019                    0
# 4                    0  0.09331305703141753                    0
# 5  0.16445282375920858                    0  0.08624081293851085
#
# 0                BC_06                BC_07               BC_07LN  \
# 1  0.11341647581821312  0.04917008115010846  0.008976045818170497
# ...

# %%
y_vals = np.array([580,580,700,943,812,912,1000,608,867,1732,987,865,932,1080,805])

# %%
yDF = pd.DataFrame(y_vals)

# %%
yDF.columns = ['days_to_live']

# %%
x_vals.head()
# Out:
# 0 Input Sample                BC_01 BC_02                BC_03  \
# 1      sample1  0.19406327581659435     0                    0
# 2      sample2   0.3761692049475335     0                    0
# 3      sample3   0.2719479143426541     0                    0
# 4      sample4  0.49188176710852854     0                    0
# 5      sample5  0.27732552765693924     0  0.09358109365128049
#
# 0              BC_03LN                BC_04                BC_05  \
# 1  0.10856565579039577  0.08307430452105279   0.2385786600008222
# 2  0.04242034472302899  0.02736060496599689  0.24217414618481348
# 3   0.1807606004816538  0.04032886742636019                    0
# 4                    0  0.09331305703141753                    0
# 5  0.16445282375920858                    0  0.08624081293851085
#
# 0                BC_06                BC_07               BC_07LN  \
# 1  0.11341647581821312  0.04917008115010846  0.008976045818170497
# ...

# %%
#Drop the non-numeric column
x_vals=x_vals.drop(['Input Sample'], axis=1)

# %%
x_vals.head()
# Out:
# 0                BC_01 BC_02                BC_03              BC_03LN  \
# 1  0.19406327581659435     0                    0  0.10856565579039577
# 2   0.3761692049475335     0                    0  0.04242034472302899
# 3   0.2719479143426541     0                    0   0.1807606004816538
# 4  0.49188176710852854     0                    0                    0
# 5  0.27732552765693924     0  0.09358109365128049  0.16445282375920858
#
# 0                BC_04                BC_05                BC_06  \
# 1  0.08307430452105279   0.2385786600008222  0.11341647581821312
# 2  0.02736060496599689  0.24217414618481348                    0
# 3  0.04032886742636019                    0  0.07803424770190256
# 4  0.09331305703141753                    0   0.0810640974298108
# 5                    0  0.08624081293851085  0.03858539219346126
#
# 0                BC_07               BC_07LN                BC_08  \
# 1  0.04917008115010846  0.008976045818170497  0.10038934840708925
# ...

# %%
x_vals.shape
# Out:
# (15, 13)

# %%
yDF.shape
# Out:
# (15, 1)

# %%
#Apply Linear Regression
regr = linear_model.LinearRegression()

# %%
regr.fit(x_vals, yDF)
# Out:
# /Users/rahulbhansali1/anaconda/lib/python3.6/site-packages/scipy/linalg/basic.py:1226: RuntimeWarning: internal gelsd driver lwork query error, required iwork dimension not returned. This is likely the result of LAPACK bug 0038, fixed in LAPACK 3.2.2 (released July 21, 2010). Falling back to 'gelss' driver.
#   warnings.warn(mesg, RuntimeWarning)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# plot it as in the example at http://scikit-learn.org/
#plt.scatter(x_vals, yDF,  color='black')
#plt.plot(x_vals, regr.predict(x_vals), color='blue', linewidth=3)
#plt.xticks(())
#plt.yticks(())
#plt.show()

# %%
x_test = np.random.rand(5,13)
y_pred = regr.predict(x_vals)

# %%
print(y_pred)
# Out:
# [[ 629.3703419 ]
#  [ 836.83490136]
#  [ 766.10949081]
#  [ 970.07669234]
#  [ 744.05399421]
#  [1033.37672341]
#  [1004.58059002]
#  [ 449.51585145]
#  [ 749.57727867]
#  [1627.50014281]
#  [ 987.00000001]
#  [ 921.58453189]
#  [ 858.30003223]
#  [1014.10361852]
#  [ 811.01581044]]

# %%
# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
#print("Mean squared error: %.2f"
#      % mean_squared_error(yDF, y_pred))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(yDF, y_pred))
# Out:
# Coefficients:
#  [[-1.09933165e+08 -1.09925360e+08 -1.09921885e+08 -1.09930700e+08
#   -1.09918428e+08 -1.09928464e+08 -1.09932281e+08 -1.09927953e+08
#   -1.09925327e+08 -1.09925311e+08 -1.09939737e+08 -1.09927621e+08
#   -1.09941236e+08]]
# Variance score: 0.86
