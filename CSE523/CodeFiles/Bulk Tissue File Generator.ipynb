# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from numpy import loadtxt
# %matplotlib inline

# %%
#Read Bulk Data file
#singleCellDF = pd.read_csv('final_single_cell_data.txt', sep='\t',header=None)
fullBulkData = pd.read_csv('TCGA_BRCA_dat.txt', sep='\t')

# %%
fullBulkData.head()
# Out:
#               A1BG|1     A2M|2  NAT1|9  NAT2|10  SERPINA3|12  SERPINA3|12.1  \
# TCGA-3C-AAAU  571.84  16823.52   23254       31      49565.0        49565.0
# TCGA-3C-AALI  436.55  13924.87    1051      157        244.0          244.0
# TCGA-3C-AALJ  466.83   9750.96    1330        1      11712.0        11712.0
# TCGA-3C-AALK  461.69  26490.85    2786       22      32425.0        32425.0
# TCGA-4H-AAAK  631.87  22525.79     307        2      24231.0        24231.0
#
#               AADAC|13  AAMP|14  AANAT|15  AARS|16           ...            \
# TCGA-3C-AAAU         0     5957         1    12794           ...
# TCGA-3C-AALI         2     5480         4     8406           ...
# TCGA-3C-AALJ         1     2528         2     2820           ...
# TCGA-3C-AALK         7     6677         1     5131           ...
# TCGA-4H-AAAK         1     7733         1     5548           ...
#
#               FRG2C|100288801  ZNF605|100289635  NHEG1|100294720  \
# ...

# %%
fullGeneNames = list(fullBulkData.columns.values)

# %%
#Preprocess the gene names to ignore stuff after '|'
geneNames = []
for gene in fullGeneNames:
    for i in range(len(gene)):
        if gene[i]=='|':
            pos = i
            geneNames.append(gene[0:pos])
            break

# %%
#singleCellDF = singleCellDF[1:] #take the data less the header row
fullBulkData.columns = geneNames #set the header row as the df header

# %%
fullBulkData.head()
# Out:
#                 A1BG       A2M   NAT1  NAT2  SERPINA3  SERPINA3  AADAC  AAMP  \
# TCGA-3C-AAAU  571.84  16823.52  23254    31   49565.0   49565.0      0  5957
# TCGA-3C-AALI  436.55  13924.87   1051   157     244.0     244.0      2  5480
# TCGA-3C-AALJ  466.83   9750.96   1330     1   11712.0   11712.0      1  2528
# TCGA-3C-AALK  461.69  26490.85   2786    22   32425.0   32425.0      7  6677
# TCGA-4H-AAAK  631.87  22525.79    307     2   24231.0   24231.0      1  7733
#
#               AANAT   AARS      ...       FRG2C  ZNF605  NHEG1  LOC100302401  \
# TCGA-3C-AAAU      1  12794      ...           0    1724      1         22.00
# TCGA-3C-AALI      4   8406      ...           1     346      0         50.12
# TCGA-3C-AALJ      2   2820      ...           0     603      0         10.00
# TCGA-3C-AALK      1   5131      ...           2     995      0         39.20
# TCGA-4H-AAAK      1   5548      ...           1    1026      0         66.25
#
# ...

# %%
#Convert FPKM to TPM
fullBulkData = fullBulkData.apply(lambda x: x*1000000/sum(x))

# %%
fullBulkData.head()
# Out:
#                      A1BG         A2M         NAT1         NAT2    SERPINA3  \
# TCGA-3C-AAAU  1070.184562  355.096192  2580.560392   512.540714  780.592391
# TCGA-3C-AALI   816.992638  293.914015   116.632363  2595.770712    3.842723
# TCGA-3C-AALJ   873.660917  205.814762   147.593761    16.533571  184.450683
# TCGA-3C-AALK   864.041533  559.145764   309.170089   363.738571  510.656880
# TCGA-4H-AAAK  1182.529237  475.454735    34.068635    33.067143  381.610698
#
#                 SERPINA3       AADAC         AAMP        AANAT         AARS  \
# TCGA-3C-AAAU  780.592391    0.000000   804.108960   704.225352  1282.559714
# TCGA-3C-AALI    3.842723   69.058389   739.720850  2816.901408   842.676017
# TCGA-3C-AALJ  184.450683   34.529194   341.243487  1408.450704   282.696451
# TCGA-3C-AALK  510.656880  241.704361   901.298561   704.225352   514.367195
# TCGA-4H-AAAK  381.610698   34.529194  1043.843309   704.225352   556.170181
#
# ...

# %%
#Apply log2(TPM + 1)
fullBulkData = fullBulkData.apply(lambda x: np.log2(x+1))

# %%
fullBulkData.head()
# Out:
#                    A1BG       A2M       NAT1       NAT2  SERPINA3  SERPINA3  \
# TCGA-3C-AAAU  10.064991  8.476123  11.334028   9.004335  9.610273  9.610273
# TCGA-3C-AALI   9.675944  8.204151   6.878141  11.342503  2.275818  2.275818
# TCGA-3C-AALJ   9.772580  7.692195   7.215230   4.132048  7.534892  7.534892
# TCGA-3C-AALK   9.756626  9.129658   8.276916   8.510719  8.999033  8.999033
# TCGA-4H-AAAK  10.208880  8.896195   5.132109   5.090309  8.579733  8.579733
#
#                  AADAC       AAMP      AANAT       AARS      ...       \
# TCGA-3C-AAAU  0.000000   9.653040   9.461941  10.325935      ...
# TCGA-3C-AALI  6.130486   9.532786  11.460405   9.720545      ...
# TCGA-3C-AALJ  5.150933   8.418879  10.460917   8.148204      ...
# TCGA-3C-AALK  7.923056   9.817461   9.461941   9.009457      ...
# TCGA-4H-AAAK  5.150933  10.029071   9.461941   9.121974      ...
#
#                  FRG2C     ZNF605      NHEG1  LOC100302401  LOC100302640  \
# ...

# %%
bulkData = fullBulkData.transpose()

# %%
bulkData.head()
# Out:
#           TCGA-3C-AAAU  TCGA-3C-AALI  TCGA-3C-AALJ  TCGA-3C-AALK  \
# A1BG         10.064991      9.675944      9.772580      9.756626
# A2M           8.476123      8.204151      7.692195      9.129658
# NAT1         11.334028      6.878141      7.215230      8.276916
# NAT2          9.004335     11.342503      4.132048      8.510719
# SERPINA3      9.610273      2.275818      7.534892      8.999033
#
#           TCGA-4H-AAAK  TCGA-5L-AAT0  TCGA-5L-AAT1  TCGA-5T-A9QA  \
# A1BG         10.208880      9.346765      8.925402     10.136008
# A2M           8.896195      8.796722      8.643884      7.016084
# NAT1          5.132109      7.195704      8.421207      7.562997
# NAT2          5.090309      8.443793      6.068978      6.867093
# SERPINA3      8.579733      8.775045      5.266713      4.764187
#
#           TCGA-A1-A0SB  TCGA-A1-A0SD      ...       TCGA-UL-AAZ6  \
# A1BG          7.682179      9.654596      ...           7.700337
# ...

# %%
#Save the bulk data file
bulkData.to_csv('bulk_data.txt', sep='\t')

# %%
bulkData.shape
# Out:
# (21022, 1094)
